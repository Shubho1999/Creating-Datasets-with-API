# %%
import requests
import pandas as pd
import numpy as np

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1').json()

# %%
response1=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=32').json()
response1
# Out:
# {'page': 32,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 24.707,
#    'vote_count': 6054,
#    'video': False,
#    'poster_path': '/bXQIL36VQdzJ69lcjQR1WQzJqQR.jpg',
#    'id': 2501,
#    'adult': False,
#    'backdrop_path': '/2Fr1vqBiDn8xRJM9elcplzHctTN.jpg',
#    'original_language': 'en',
#    'original_title': 'The Bourne Identity',
#    'genre_ids': [28, 18, 9648, 53],
#    'title': 'The Bourne Identity',
#    'vote_average': 7.4,
#    'overview': 'Wounded to the brink of death and suffering from amnesia, Jason Bourne is rescued at sea by a fisherman. With nothing to go on but a Swiss bank account number, he starts to reconstruct his life, but finds that many people he encounters want him dead. However, Bourne realizes that he has the combat and mental skills of a world-class spy—but who does he work for?',
#    'release_date': '2002-06-14'},
#   {'popularity': 24.706,
#    'vote_count': 1950,
#    'video': False,
#    'poster_path': '/7LEI8ulZzO5gy9Ww2NVCrKmHeDZ.jpg',
#    'id': 530385,
#    'adult': False,
#    'backdrop_path': '/g6GtOfXtzDpY73ef7wludoorTti.jpg',
#    'original_language': 'en',
#    'original_title': 'Midsommar',
#    'genre_ids': [18, 27, 9648],
#    'title': 'Midsommar',
#    'vote_average': 7.1,
#    'overview': 'Several friends travel to Sweden to study as anthropologists a summer festival that is held every ninety years in the remote hometown of one of them. What begins as a dream vacation in a place where the sun never sets, gradually turns into a dark nightmare as the mysterious inhabitants invite them to participate in their disturbing festive activities.',
#    'release_date': '2019-07-03'},
#   {'popularity': 24.706,
#    'vote_count': 36,
#    'video': False,
#    'poster_path': '/2qkaLzpsC0X3zYwjhh1GPsjny2.jpg',
#    'id': 122126,
#    'adult': False,
#    'backdrop_path': '/zgx6bBaVLAsFO5ip7gwndOjhE7U.jpg',
#    'original_language': 'ko',
#    'original_title': '후궁: 제왕의 첩',
#    'genre_ids': [18],
#    'title': 'The Concubine',
#    'vote_average': 6,
#    'overview': 'Living a torturous life of poverty and barely able to survive, Hwa-yeon decides to offer herself as one of the king’s concubines. Once inside the royal palace, two men are immediately seized by the woman -- the Grand Prince Seong-won, a megalomaniacal ruler drunk with power and lust, and Kwon-yoo, who has everything to lose if his desire for Hwa-yeon is exposed.',
#    'release_date': '2012-06-06'},
#   {'popularity': 24.698,
#    'vote_count': 9421,
#    'video': False,
#    'poster_path': '/yDxsfIkbAJp5LrIsGCXRE8MwAZg.jpg',
#    'id': 273248,
#    'adult': False,
#    'backdrop_path': '/2DCU7Ou54JiBwTIarzKywtHPbAe.jpg',
#    'original_language': 'en',
#    'original_title': 'The Hateful Eight',
#    'genre_ids': [80, 18, 9648, 37],
#    'title': 'The Hateful Eight',
#    'vote_average': 7.7,
#    'overview': 'Bounty hunters seek shelter from a raging blizzard and get caught up in a plot of betrayal and deception.',
#    'release_date': '2015-12-25'},
#   {'popularity': 24.698,
#    'vote_count': 3777,
#    'video': False,
#    'poster_path': '/ifzddUhnsTf1h6guBUKBlDwuS1t.jpg',
#    'id': 364,
#    'adult': False,
#    'backdrop_path': '/reQewz6KndV7Js2mfLfaaX8Rj0T.jpg',
#    'original_language': 'en',
#    'original_title': 'Batman Returns',
#    'genre_ids': [28, 14],
#    'title': 'Batman Returns',
#    'vote_average': 6.8,
#    'overview': 'Having defeated the Joker, Batman now faces the Penguin—a warped and deformed individual who is intent on being accepted into Gotham society, with the help of Max Schreck, a crooked businessman, whom he coerces into helping him run for the position of Mayor of Gotham, while they both attempt to frame Batman in a different light. Batman must attempt to clear his name, all while also deciding just what must be done with the mysterious Catwoman slinking about.',
#    'release_date': '1992-06-19'},
#   {'popularity': 24.68,
#    'id': 20352,
#    'video': False,
#    'vote_count': 11062,
#    'vote_average': 7.2,
#    'title': 'Despicable Me',
#    'release_date': '2010-07-08',
#    'original_language': 'en',
#    'original_title': 'Despicable Me',
#    'genre_ids': [16, 10751],
#    'backdrop_path': '/yo1ef57MEPkEE4BDZKTZGH9uDcX.jpg',
#    'adult': False,
#    'overview': 'Villainous Gru lives up to his reputation as a despicable, deplorable and downright unlikable guy when he hatches a plan to steal the moon from the sky. But he has a tough time staying on task after three orphans land in his care.',
#    'poster_path': '/4zHJhBSY4kNZXfhTlmy2TzXD51M.jpg'},
#   {'popularity': 24.675,
#    'vote_count': 11410,
#    'video': False,
#    'poster_path': '/8x7ej0LnHdKUqilNNJXYOeyB6L9.jpg',
#    'id': 207703,
#    'adult': False,
#    'backdrop_path': '/7McaexSsSTLD8V17UgaZAfI0Cu9.jpg',
#    'original_language': 'en',
#    'original_title': 'Kingsman: The Secret Service',
#    'genre_ids': [28, 12, 35, 80],
#    'title': 'Kingsman: The Secret Service',
#    'vote_average': 7.6,
#    'overview': "The story of a super-secret spy organization that recruits an unrefined but promising street kid into the agency's ultra-competitive training program just as a global threat emerges from a twisted tech genius.",
#    'release_date': '2014-12-13'},
#   {'popularity': 24.663,
#    'vote_count': 5648,
#    'video': False,
#    'poster_path': '/yhIsVvcUm7QxzLfT6HW2wLf5ajY.jpg',
#    'id': 564,
#    'adult': False,
#    'backdrop_path': '/7rz4sMD7Ku0E4KIqYezxoiSzTMj.jpg',
#    'original_language': 'en',
#    'original_title': 'The Mummy',
#    'genre_ids': [28, 12, 14],
#    'title': 'The Mummy',
#    'vote_average': 6.8,
#    'overview': "Dashing legionnaire Rick O'Connell stumbles upon the hidden ruins of Hamunaptra while in the midst of a battle to claim the area in 1920s Egypt. It has been over three thousand years since former High Priest Imhotep suffered a fate worse than death as a punishment for a forbidden love—along with a curse that guarantees eternal doom upon the world if he is ever awoken.",
#    'release_date': '1999-04-16'},
#   {'popularity': 24.654,
#    'vote_count': 711,
#    'video': False,
#    'poster_path': '/q1epO0eO8DWu8Vo8tPfvVlzW48T.jpg',
#    'id': 481084,
#    'adult': False,
#    'backdrop_path': '/ur4NTeFGZmQ6Hz5uEkAMgPI3WRg.jpg',
#    'original_language': 'en',
#    'original_title': 'The Addams Family',
#    'genre_ids': [16, 35, 14, 10751],
#    'title': 'The Addams Family',
#    'vote_average': 6.2,
#    'overview': "The Addams family's lives begin to unravel when they face-off against a treacherous, greedy crafty reality-TV host while also preparing for their extended family to arrive for a major celebration.",
#    'release_date': '2019-10-10'},
#   {'popularity': 24.647,
#    'vote_count': 1374,
#    'video': False,
#    'poster_path': '/lj8AMCjWx0jU93XajzUEOUUNKZF.jpg',
#    'id': 154400,
#    'adult': False,
#    'backdrop_path': '/lI7TD9Z9TsASnc3GxkLbBBpXCac.jpg',
#    'original_language': 'en',
#    'original_title': 'The Drop',
#    'genre_ids': [80, 18],
#    'title': 'The Drop',
#    'vote_average': 6.7,
#    'overview': "Bob Saginowski finds himself at the center of a robbery gone awry and entwined in an investigation that digs deep into the neighborhood's past where friends, families, and foes all work together to make a living - no matter the cost.",
#    'release_date': '2014-09-12'},
#   {'popularity': 24.633,
#    'vote_count': 11252,
#    'video': False,
#    'poster_path': '/4mFsNQwbD0F237Tx7gAPotd0nbJ.jpg',
#    'id': 77338,
#    'adult': False,
#    'backdrop_path': '/ihWaJZCUIon2dXcosjQG2JHJAPN.jpg',
#    'original_language': 'fr',
#    'original_title': 'Intouchables',
#    'genre_ids': [35, 18],
#    'title': 'The Intouchables',
#    'vote_average': 8.2,
#    'overview': 'A true story of two men who should never have met – a quadriplegic aristocrat who was injured in a paragliding accident and a young man from the projects.',
#    'release_date': '2011-11-02'},
#   {'popularity': 24.63,
#    'vote_count': 730,
#    'video': False,
#    'poster_path': '/xHYsUwUe4MaNc6mbNBGTkqZSnPk.jpg',
#    'id': 15165,
#    'adult': False,
#    'backdrop_path': '/hAEQCcfA05wP2SplosJn1dkienN.jpg',
#    'original_language': 'en',
#    'original_title': 'Barbie as The Princess & the Pauper',
#    'genre_ids': [16, 35, 10751],
#    'title': 'Barbie as The Princess & the Pauper',
#    'vote_average': 7.4,
#    'overview': 'In her first animated musical featuring seven original songs, Barbie comes to life in this modern re-telling of a classic tale of mistaken identity and the power of friendship. Based on the story by Mark Twain,',
#    'release_date': '2004-09-28'},
#   {'popularity': 24.611,
#    'vote_count': 8080,
#    'video': False,
#    'poster_path': '/j87XPCcAnJUnjQ0gvZoWS6XQpfh.jpg',
#    'id': 61791,
#    'adult': False,
#    'backdrop_path': '/oxrovtv9Yo9snk4WLM0bK0SCRES.jpg',
#    'original_language': 'en',
#    'original_title': 'Rise of the Planet of the Apes',
#    'genre_ids': [28, 18, 878, 53],
#    'title': 'Rise of the Planet of the Apes',
#    'vote_average': 7.2,
#    'overview': "Scientist Will Rodman is determined to find a cure for Alzheimer's, the disease which has slowly consumed his father. Will feels certain he is close to a breakthrough and tests his latest serum on apes, noticing dramatic increases in intelligence and brain activity in the primate subjects – especially Caesar, his pet chimpanzee.",
#    'release_date': '2011-08-03'},
#   {'popularity': 24.609,
#    'id': 398818,
#    'video': False,
#    'vote_count': 6400,
#    'vote_average': 8.3,
#    'title': 'Call Me by Your Name',
#    'release_date': '2017-09-01',
#    'original_language': 'en',
#    'original_title': 'Call Me by Your Name',
#    'genre_ids': [10749, 18],
#    'backdrop_path': '/64OtTrXNyLwbqWBcd9JBsJmZb7w.jpg',
#    'adult': False,
#    'overview': "In 1980s Italy, a relationship begins between seventeen-year-old teenage Elio and the older adult man hired as his father's research assistant.",
#    'poster_path': '/tcNniniS4rfqrLH0oORikJfnIwY.jpg'},
#   {'popularity': 24.545,
#    'vote_count': 4918,
#    'video': False,
#    'poster_path': '/3bQHHXuzZDu2Ju3VFjIM72E9TSw.jpg',
#    'id': 60304,
#    'adult': False,
#    'backdrop_path': '/8SYTYMg4ePSvzkCBte7dpX2sFpQ.jpg',
#    'original_language': 'en',
#    'original_title': 'Hansel & Gretel: Witch Hunters',
#    'genre_ids': [28, 14, 27],
#    'title': 'Hansel & Gretel: Witch Hunters',
#    'vote_average': 5.9,
#    'overview': 'After getting a taste for blood as children, Hansel and Gretel have become the ultimate vigilantes, hell-bent on retribution. Now, unbeknownst to them, Hansel and Gretel have become the hunted, and must face an evil far greater than witches... their past.',
#    'release_date': '2013-01-17'},
#   {'popularity': 24.534,
#    'id': 11036,
#    'video': False,
#    'vote_count': 7138,
#    'vote_average': 7.9,
#    'title': 'The Notebook',
#    'release_date': '2004-06-25',
#    'original_language': 'en',
#    'original_title': 'The Notebook',
#    'genre_ids': [10749, 18],
#    'backdrop_path': '/7BBG6Kq5psKQByX0xgyTzoGhT3v.jpg',
#    'adult': False,
#    'overview': "An epic love story centered around an older man who reads aloud to a woman with Alzheimer's. From a faded notebook, the old man's words bring to life the story about a couple who is separated by World War II, and is then passionately reunited, seven years later, after they have taken different paths.",
#    'poster_path': '/gMfstesBXKdsHToAUXVPHujUDfb.jpg'},
#   {'popularity': 24.497,
#    'genre_ids': [28, 10752],
#    'video': False,
#    'vote_count': 0,
#    'original_language': 'zh',
#    'adult': False,
#    'title': 'Wolf Warrior 3',
#    'original_title': '战狼3',
#    'backdrop_path': None,
#    'id': 504075,
#    'vote_average': 0,
#    'overview': 'The third movie about a Chinese special force soldier with extraordinary marksmanship.',
#    'poster_path': '/detm29wsfhS1bz5YdURvDePiUY3.jpg'},
#   {'popularity': 24.494,
#    'vote_count': 4621,
#    'video': False,
#    'poster_path': '/vXjVd0Vu0MXRZnga7wEnHIIhO5B.jpg',
#    'id': 137,
#    'adult': False,
#    'backdrop_path': '/dTUH9xO3w6vQjcN2ictxgpnAhKm.jpg',
#    'original_language': 'en',
#    'original_title': 'Groundhog Day',
#    'genre_ids': [35, 18, 14, 10749],
#    'title': 'Groundhog Day',
#    'vote_average': 7.5,
#    'overview': 'A narcissistic T.V. weatherman, along with his attractive-but-distant producer and mawkish cameraman, is sent to report on Groundhog Day in the small town of Punxsutawney, where he finds himself repeating the same day over and over.',
#    'release_date': '1993-02-11'},
#   {'popularity': 24.491,
#    'vote_count': 0,
#    'video': False,
#    'poster_path': '/jYoRYxB56YU7CmqU4BfDWIuHZUX.jpg',
#    'id': 390635,
#    'adult': False,
#    'backdrop_path': None,
#    'original_language': 'ja',
#    'original_title': "劇場版 Fate／stay night [Heaven's Feel] III.spring song",
#    'genre_ids': [16],
#    'title': "Fate/Stay Night: Heaven's Feel III. Spring Song",
#    'vote_average': 0,
#    'overview': 'Theatrical-release adaptation of the visual novel "Fate/stay night", following the third and final route. (Final part of a trilogy.)',
#    'release_date': '2020-03-28'},
#   {'popularity': 24.491,
#    'vote_count': 0,
#    'video': False,
#    'poster_path': '/aKx1ARwG55zZ0GpRvU2WrGrCG9o.jpg',
#    'id': 337401,
#    'adult': False,
#    'backdrop_path': '/xl5oCFLVMo4d4Pgxvrf8Jmc2IlA.jpg',
#    'original_language': 'en',
#    'original_title': 'Mulan',
#    'genre_ids': [28, 18, 10752],
#    'title': 'Mulan',
#    'vote_average': 0,
#    'overview': 'When the Emperor of China issues a decree that one man per family must serve in the Imperial Chinese Army to defend the country from Huns, Hua Mulan, the eldest daughter of an honored warrior, steps in to take the place of her ailing father. She is spirited, determined and quick on her feet. Disguised as a man by the name of Hua Jun, she is tested every step of the way and must harness her innermost strength and embrace her true potential.',
#    'release_date': '2020-12-31'}]}

# %%
for i in response1['results']:
    print(i['release_date'])
# Out:
# 2002-06-14
# 2019-07-03
# 2012-06-06
# 2015-12-25
# 1992-06-19
# 2010-07-08
# 2014-12-13
# 1999-04-16
# 2019-10-10
# 2014-09-12
# 2011-11-02
# 2004-09-28
# 2011-08-03
# 2017-09-01
# 2013-01-17
# 2004-06-25
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-fad401c1c65a> in <module>
#       1 for i in response1['results']:
# ----> 2     print(i['release_date'])
#
# KeyError: 'release_date'

# %%
d={'name':['Rahul','Rohit'],'Age':[34,56]}
df=pd.DataFrame(d)
df
# Out:
#     name  Age
# 0  Rahul   34
# 1  Rohit   56

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]



for i in response['results']:
    print(i['title'],i['vote_average'])
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}
df=pd.DataFrame(d)
df
# Out:
# John Wick 7.2
# Ad Astra 6
# Bad Boys for Life 6.9
# The Lion King 7.1
# Jurassic World: Fallen Kingdom 6.5
# Bloodshot 7.3
# Motherless Brooklyn 6.9
# Transformers: The Last Knight 6
# Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn) 7.1
# Barbie and the Diamond Castle 7.1
# The Platform 7.2
# Underwater 6.4
# Star Wars: The Rise of Skywalker 6.5
# Sonic the Hedgehog 7.4
# Hotel Transylvania 2 6.7
# Jumanji: The Next Level 6.8
# The Invisible Man 7.1
# Atlantis: The Lost Empire 6.9
# Geostorm 5.8
# Onward 8
#                                                 title  \
# 0                                           John Wick
# 1                                            Ad Astra
# 2                                   Bad Boys for Life
# 3                                       The Lion King
# 4                      Jurassic World: Fallen Kingdom
# 5                                           Bloodshot
# 6                                 Motherless Brooklyn
# 7                       Transformers: The Last Knight
# 8   Birds of Prey (and the Fantabulous Emancipatio...
# 9                       Barbie and the Diamond Castle
# 10                                       The Platform
# 11                                         Underwater
# 12                   Star Wars: The Rise of Skywalker
# 13                                 Sonic the Hedgehog
# 14                               Hotel Transylvania 2
# 15                            Jumanji: The Next Level
# 16                                  The Invisible Man
# 17                          Atlantis: The Lost Empire
# 18                                           Geostorm
# 19                                             Onward
#
#                                              overview original_language  \
# 0   Ex-hitman John Wick comes out of retirement to...                en
# 1   The near future, a time when both hope and har...                en
# 2   Marcus and Mike are forced to confront new thr...                en
# 3   Simba idolizes his father, King Mufasa, and ta...                en
# 4   Three years after the demise of Jurassic World...                en
# 5   After he and his wife are murdered, marine Ray...                en
# 6   New York City, 1957. Lionel Essrog, a private ...                en
# 7   Autobots and Decepticons are at war, with huma...                en
# 8   Harley Quinn joins forces with a singer, an as...                en
# 9   Liana and Alexa (Barbie and Teresa) are best f...                en
# 10  A mysterious place, an indescribable prison, a...                es
# 11  After an earthquake destroys their underwater ...                en
# 12  The surviving Resistance faces the First Order...                en
# 13  Based on the global blockbuster videogame fran...                en
# 14  When the old-old-old-fashioned vampire Vlad ar...                en
# 15  As the gang return to Jumanji to rescue one of...                en
# 16  When Cecilia's abusive ex takes his own life a...                en
# 17  The world's most highly qualified crew of arch...                en
# 18  After an unprecedented series of natural disas...                en
# 19  In a suburban fantasy world, two teenage elf b...                en
#
#    release_date  popularity  vote_count  vote_average
# 0    2014-10-22     818.916       12063           7.2
# 1    2019-09-17     427.078        2778           6.0
# 2    2020-01-15     372.268        2062           6.9
# 3    2019-07-12     366.904        5043           7.1
# 4    2018-06-06     355.501        7153           6.5
# 5    2020-02-20     336.364        1153           7.3
# 6    2019-10-31     274.351         410           6.9
# 7    2017-06-16     239.659        3720           6.0
# 8    2020-02-05     228.535        2419           7.1
# 9    2008-01-01     222.339         456           7.1
# 10   2019-11-08     222.136        1581           7.2
# 11   2020-01-08     194.985         434           6.4
# 12   2019-12-18     191.652        3704           6.5
# 13   2020-02-12     189.881        1860           7.4
# 14   2015-09-21     182.633        3620           6.7
# 15   2019-12-04     167.871        2811           6.8
# 16   2020-02-26     162.811        1080           7.1
# 17   2001-06-02     148.821        2966           6.9
# 18   2017-10-13     141.067        2670           5.8
# 19   2020-02-29     140.272         746           8.0

# %%
final=pd.DataFrame()

for j in range(1,501):
    
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(j)).json()
    
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]



    for i in response['results']:
        
        try:
            
            
            popularity.append(i['popularity'])
        
        except:
            
            popularity.append(np.nan)
        try:
            
            vote_count.append(i['vote_count'])
        
        except:
            
            vote_count.append(np.nan)
        
        try:
            
            
            original_language.append(i['original_language'])
        
        except:
            
            original_language(np.nan)
        
        try:
            
            
            title.append(i['title'])
        
        
        except:
            
            title.append(np.nan)
        
        try:
            
            
            vote_average.append(i['vote_average'])
        
        
        except:
            
            vote_average.append(np.nan)
        
        try:
            
            
            overview.append(i['overview'])
        
        
        except:
            
            
            overview.append(np.nan)
        
        try:
            
            release_date.append(i['release_date'])
        
        
        except:
            
            release_date.append(np.nan)
        
    
    d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}
    df=pd.DataFrame(d)
    
    final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                                                   title  \
# 0                        Jurassic World: Fallen Kingdom
# 1                                              Ad Astra
# 2                                     Bad Boys for Life
# 3                         Transformers: The Last Knight
# 4                                             Bloodshot
# 5                                            Underwater
# 6     Birds of Prey (and the Fantabulous Emancipatio...
# 7                                         The Lion King
# 8                             Atlantis: The Lost Empire
# 9                                          The Platform
# 10                                             Geostorm
# 11                           Die Hard: With a Vengeance
# 12                     Star Wars: The Rise of Skywalker
# 13            13 Hours: The Secret Soldiers of Benghazi
# 14                                   Sonic the Hedgehog
# 15                                 Hotel Transylvania 2
# 16                              Jumanji: The Next Level
# 17                      Cinderella II: Dreams Come True
# 18                                  Motherless Brooklyn
# 19                                               Onward
# 20                                    The Invisible Man
# 21                                            John Wick
# 22                        Barbie and the Diamond Castle
# 23                                             The Hunt
# 24                                             365 Days
# 25                       Percy Jackson: Sea of Monsters
# 26                                Miracle in Cell No. 7
# 27                                 The Call of the Wild
# 28                                              Ant-Man
# 29                                                Joker
# ...                                                 ...
# 9970                                           Paperman
# 9971                                         Cousinhood
# 9972                                              Ordet
# 9973                                     Certified Copy
# 9974                                      The Innocents
# 9975                               Ask Me If I Am Happy
# 9976                          Invasion of Astro-Monster
# 9977                                           Cyborg 2
# 9978                                          Chocolate
# 9979                                        City of Men
# 9980                                 The Great Outdoors
# 9981                                     Upstream Color
# 9982                                Trouble in Paradise
# 9983                                           THX 1138
# 9984             Jonas Brothers: The Concert Experience
# 9985                                 Tarzan the Ape Man
# 9986                                          Walled In
# 9987                                      The Producers
# 9988                                The Four Musketeers
# 9989                                      The Extra Man
# 9990                                          Ong Bak 2
# 9991                                        Dead Season
# 9992                                       Kill Command
# 9993                                           The Deep
# 9994                                Eye of the Beholder
# 9995                                         Borderland
# 9996                           The Haunting of Alcatraz
# 9997                                 And Then We Danced
# 9998                                        The Nursery
# 9999                               The Art of the Steal
#
#                                                overview original_language  \
# 0     Three years after the demise of Jurassic World...                en
# 1     The near future, a time when both hope and har...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     Autobots and Decepticons are at war, with huma...                en
# 4     After he and his wife are murdered, marine Ray...                en
# 5     After an earthquake destroys their underwater ...                en
# 6     Harley Quinn joins forces with a singer, an as...                en
# 7     Simba idolizes his father, King Mufasa, and ta...                en
# 8     The world's most highly qualified crew of arch...                en
# 9     A mysterious place, an indescribable prison, a...                es
# 10    After an unprecedented series of natural disas...                en
# 11    New York detective John McClane is back and ki...                en
# 12    The surviving Resistance faces the First Order...                en
# 13    An American Ambassador is killed during an att...                en
# 14    Based on the global blockbuster videogame fran...                en
# 15    When the old-old-old-fashioned vampire Vlad ar...                en
# 16    As the gang return to Jumanji to rescue one of...                en
# 17    As a newly crowned princess, Cinderella quickl...                en
# 18    New York City, 1957. Lionel Essrog, a private ...                en
# 19    In a suburban fantasy world, two teenage elf b...                en
# 20    When Cecilia's abusive ex takes his own life a...                en
# 21    Ex-hitman John Wick comes out of retirement to...                en
# 22    Liana and Alexa (Barbie and Teresa) are best f...                en
# 23    Twelve strangers wake up in a clearing. They d...                en
# 24    Laura, in order to save her relationship from ...                pl
# 25    In their quest to confront the ultimate evil, ...                en
# 26    Separated from his daughter, a father with an ...                tr
# 27    Buck is a big-hearted dog whose blissful domes...                en
# 28    Armed with the astonishing ability to shrink i...                en
# 29    During the 1980s, a failed stand-up comedian i...                en
# ...                                                 ...               ...
# 9970  An urban office worker finds that paper airpla...                en
# 9971  Three cousins travel to the village where they...                es
# 9972  The three sons of devout Danish farmer Morten ...                da
# 9973  In Tuscany to promote his latest book, a middl...                fr
# 9974  A young governess for two children becomes con...                en
# 9975  Aspiring actors travel to Sicily after hearing...                it
# 9976  Mysterious aliens known as Xiliens arrive from...                ja
# 9977  In the year 2074, the cybernetics market is do...                en
# 9978  Zen, an autistic teenage girl with powerful ma...                th
# 9979  Best buddies Acerola and Laranjinha, about to ...                pt
# 9980  It's vacation time for outdoorsy Chicago man C...                en
# 9981  A man and woman are drawn together, entangled ...                en
# 9982  Thief Gaston Monescu and pickpocket Lily are p...                en
# 9983  People in the future live in a totalitarian so...                en
# 9984  Secure your VIP pass to a once-in-a-lifetime e...                en
# 9985  James Parker and Harry Holt are on an expediti...                en
# 9986  Having finally secured her first assignment fr...                en
# 9987  After putting together another Broadway flop, ...                en
# 9988  The Four Musketeers defend the queen and her d...                en
# 9989  THE EXTRA MAN is a sophisticated and moving co...                en
# 9990  Moments from death a young man is rescued by a...                th
# 9991  It has been over one year since the start of t...                en
# 9992  Set in a near future, technology-reliant socie...                en
# 9993  A pair of young vacationers are involved in a ...                en
# 9994  A reclusive surveillance expert is hired to sp...                en
# 9995  Three college students, Phil, Ed, and Henry ta...                en
# 9996  Alcatraz. 1937. A young prison guard working t...                en
# 9997  Merab has been training since a young age at t...                ka
# 9998  When college freshman Ranae agrees to babysit ...                en
# 9999  Crunch Calhoun, a third-rate motorcycle darede...                en
#
#      release_date  popularity  vote_count  vote_average
# 0      2018-06-06     497.701        7173           6.5
# 1      2019-09-17     405.902        2786           6.0
# 2      2020-01-15     351.268        2184           7.0
# 3      2017-06-16     335.523        3723           6.0
# 4      2020-02-20     305.220        1194           7.3
# 5      2020-01-08     260.207         466           6.4
# 6      2020-02-05     228.989        2452           7.1
# 7      2019-07-12     220.142        5073           7.1
# 8      2001-06-02     208.349        2972           6.9
# 9      2019-11-08     197.542        1655           7.2
# 10     2017-10-13     197.494        2677           5.8
# 11     1995-05-19     194.492        3725           7.1
# 12     2019-12-18     191.366        3720           6.5
# 13     2016-01-13     184.740        1869           7.1
# 14     2020-02-12     182.683        1899           7.4
# 15     2015-09-21     174.255        3623           6.7
# 16     2019-12-04     173.230        2837           6.8
# 17     2002-02-23     165.369         853           5.9
# 18     2019-10-31     164.611         412           6.9
# 19     2020-02-29     147.113         787           8.0
# 20     2020-02-26     145.203        1108           7.1
# 21     2014-10-22     540.987       12081           7.2
# 22     2008-01-01     133.403         456           7.1
# 23     2020-03-11     127.454         291           6.8
# 24     2020-02-07     127.000          95           5.5
# 25     2013-08-07     125.948        3527           5.9
# 26     2019-10-10     120.530        1278           8.5
# 27     2020-02-19     119.445         341           6.7
# 28     2015-07-14     118.982       13567           7.1
# 29     2019-10-02     114.251       10739           8.2
# ...           ...         ...         ...           ...
# 9970   2012-11-02       9.070        1227           8.1
# 9971   2011-02-04       9.070          99           6.8
# 9972   1955-01-09       9.070         148           8.0
# 9973   2010-05-18       9.069         189           7.1
# 9974   1961-12-15       9.069         250           7.5
# 9975   2000-12-15       9.068        1076           7.6
# 9976   1965-12-19       9.068          60           6.4
# 9977   1993-11-24       9.068          60           4.3
# 9978   2008-02-06       9.068         175           7.1
# 9979   2007-08-31       9.068         151           7.1
# 9980   1988-06-17       9.068         280           6.5
# 9981   2013-04-05       9.067         473           6.5
# 9982   1932-10-30       9.067         117           7.7
# 9983   1971-03-11       9.066         483           6.6
# 9984   2009-02-27       9.064          55           6.2
# 9985   1932-04-02       9.064          90           6.5
# 9986   2009-02-20       9.064         106           4.8
# 9987   2005-12-25       9.064         282           6.3
# 9988   1974-10-31       9.063          90           6.5
# 9989   2010-08-01       9.062          49           6.0
# 9990   2008-12-04       9.062         313           6.1
# 9991   2012-05-15       9.061          30           4.5
# 9992   2016-05-13       9.059         324           5.2
# 9993   1977-06-17       9.059         108           6.2
# 9994   1999-09-04       9.059          80           5.0
# 9995   2007-11-09       9.059         108           5.2
# 9996   2020-03-09       9.057           0           0.0
# 9997   2019-09-13       9.057          38           8.0
# 9998   2018-06-15       9.057          10           3.6
# 9999   2013-09-11       9.056         339           6.2
#
# [10000 rows x 7 columns]

# %%
final.to_csv('movies.csv')
